# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot ( [ 1.5, 3.5, - 2, 1.6] )

# %%
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--')

# %%
import numpy as np
_ = ax1.hist(randn(100), bins = 20, color = 'k', alpha = 0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
fig, axes = plt.subplots(2, 3)
plt.xlim([0,50])
plt.ylim([0,50])
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f45b8abf550>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45b8962eb8>]], dtype=object)

# %%
plt.plot(randn(20), color = 'k', linestyle = '-', marker = 'o')

# %%
data = randn(20).cumsum()
plt.plot(data, 'k-', label='steps-post', drawstyle='steps-post')
plt.legend(loc='best')

# %%
fig = plt.figure(); ax = fig.add_subplot(1,1,1)
ticks = ax.set_xticks([200, 400, 600, 800, 1000])
ax.set_title('My first plot')
ax.set_xlabel('Stages')
ax.set_ylabel('Something')
ax.plot(randn(1000).cumsum(), label='one')
ax.plot(randn(1000).cumsum(), label='two')
ax.plot(randn(1000).cumsum(), label='three')
ax.legend(loc='best')

# %%
fig = plt.figure(); ax = fig.add_subplot(1,1,1)
ticks = ax.set_xticks([200, 400, 600, 800, 1000])
ax.set_title('My first plot')
ax.set_xlabel('Stages')
ax.set_ylabel('Something')
ax.plot(randn(1000).cumsum(), label='one')
ax.legend(loc='best')
ax.text(10, 10, 'Hello, plot', family='monospace', fontsize=10)

# %%
import pandas as pd
from datetime import datetime
fig = plt.figure()
ax=fig.add_subplot(1,1,1)
data = pd.read_csv('ch008/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']
spx.plot(ax=ax, style='k-')

crisis_data=[
(datetime(2007, 10, 11), 'Peak of bull market'),
(datetime(2008, 3, 12), 'Bear Stearns Fails'),
(datetime(2008, 9, 15), 'Lehman Bankruptcy')
            ]
for data, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
               xytext=(date, spx.asof(date) + 200),
               arrowprops= dict(facecolor = 'Ьlack'),
               horizontalaligrunent= 'left', verticalalignment='top')
ax.set_xlim(['1/1/2007', '1,1,2011'])
ax.set_ylim([600, 1800])
# Out:
# /opt/conda/lib/python3.6/site-packages/numexpr/cpuinfo.py:42: UserWarning: [Errno 12] Cannot allocate memory
#   warnings.warn(str(e), UserWarning, stacklevel=stacklevel)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-153-7eb4c688f7cb> in <module>()
#       3 fig = plt.figure()
#       4 ax=fig.add_subplot(1,1,1)
# ----> 5 data = pd.read_csv('ch008/spx.csv', index_col=0, parse_dates=True)
#       6 spx = data['SPX']
#       7 spx.plot(ax=ax, style='k-')
#
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color = 'r', alpha= 0.5)
ax.add_patch(rect)

# %%
plt.savefig('fig.svg')
